# %% [markdown]
# <a href="https://colab.research.google.com/github/pedrozinn2102/DataScience/blob/main/Aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pedro Zinn

# %%
print("Olá Mundo")
# Out:
# Olá Mundo
